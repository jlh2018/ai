# %% [markdown]
# <font size="+3">【AI精研社】精讲 李航老师《统计学习方法 (第2版)》 </font>

# %% [markdown]
# <center><font size="+3">第3章 k 近邻法</font></center>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <center><font size="+3">第17章 潜在语义分析 </font></center>

# %% [markdown]
# <center><font size="+3">第15章 SVD (奇异值分解) </font></center>
